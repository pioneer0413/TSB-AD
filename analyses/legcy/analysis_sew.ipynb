# %%
import torch
import torchinfo
from spikingjelly.activation_based import neuron, surrogate, layer
from spikingjelly.activation_based.model import sew_resnet

# %%
sew_resnet18 = sew_resnet.sew_resnet18(
    spiking_neuron=neuron.IFNode,
)
sew_resnet18.conv1 = layer.Conv2d(
            in_channels=1,
            out_channels=64,
            kernel_size=(7,7),
            stride=(2,2),
            padding=(3,3),
            bias=False,
            step_mode='s')

# %%
print(sew_resnet18)
# Out:
# SEWResNet(
#   (conv1): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False, step_mode=s)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True, step_mode=s)
#   (sn1): IFNode(
#     v_threshold=1.0, v_reset=0.0, detach_reset=False, step_mode=s, backend=torch
#     (surrogate_function): Sigmoid(alpha=4.0, spiking=True)
#   )
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False, step_mode=s)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       cnf=None
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, step_mode=s)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True, step_mode=s)
#       (sn1): IFNode(
#         v_threshold=1.0, v_reset=0.0, detach_reset=False, step_mode=s, backend=torch
#         (surrogate_function): Sigmoid(alpha=4.0, spiking=True)
#       )
# ...
