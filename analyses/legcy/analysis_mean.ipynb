# %%
import os
import pandas as pd

# %%
file_path = '/home/hwkang/dev-TSB-AD/TSB-AD/results/smap/421_CNN_None_kpca.csv'

# %%
df = pd.read_csv(file_path)

# %%
df.describe()
# Out:
#             Time     AUC-PR    AUC-ROC     VUS-PR    VUS-ROC  Standard-F1  \
# count  25.000000  25.000000  25.000000  25.000000  25.000000    25.000000
# mean    9.553757   0.341477   0.699402   0.350925   0.767335     0.421619
# std     3.920330   0.299055   0.174458   0.277489   0.160855     0.283262
# min     2.608707   0.003866   0.292979   0.011586   0.316799     0.012074
# 25%     6.292178   0.069838   0.598851   0.100208   0.678247     0.202530
# 50%    10.523926   0.254552   0.686349   0.297550   0.759196     0.428265
# 75%    12.339180   0.656887   0.795735   0.624465   0.896200     0.601022
# max    15.489350   0.937339   0.990488   0.813880   0.990924     0.953120
#
#            PA-F1  Event-based-F1  R-based-F1  Affiliation-F
# count  25.000000       25.000000   25.000000      25.000000
# mean    0.935373        0.841227    0.402886       0.929600
# std     0.198082        0.309792    0.218452       0.115502
# min     0.044062        0.012215    0.034685       0.666655
# ...
